# %%
import os
import pandas as pd
import numpy as np
import re
from datetime import datetime
import arrow
import pathlib

# %%
import numpy as np
import netCDF4 as nc
import pandas as pd
import numpy.ma as ma
import matplotlib as mpl
import matplotlib.pyplot as pltz
import xarray as xar
import rioxarray

# %%
dir_to_read=r'F:\03nginx_data\nmefc_download\TY_GROUP_RESULT\TY2022_2021010416'
file_name='proSurge_TY2022_2021010416_gt1_0m.nc'
file_converted_name=file_name.split('.')[0]+'_converted.'+file_name.split('.')[1]
read_full_path=str(pathlib.Path(dir_to_read)/file_name)
read_full_path
# Out:
# 'F:\\03nginx_data\\nmefc_download\\TY_GROUP_RESULT\\TY2022_2021010416\\proSurge_TY2022_2021010416_gt1_0m.nc'

# %%
ds_xr=xar.open_dataset(read_full_path)
ds_xr=ds_xr.rename_vars({'latitude':'y','longitude':'x'})
ds_xr=ds_xr.swap_dims({'lat':'y','lon':'x'})
ds_xr.rio.set_spatial_dims("x","y",inplace=True)
ds_xr=ds_xr.rio.write_crs("epsg:4326", inplace=True)

# %% [markdown]
# * 注意此处缺少 coords,设置了坐标系

# %% [markdown]
# 注意使用 rioxarray -> geotiff 时，需要将 lon -> x, lat -> y

# %% [markdown]
# 注意此处还需要加入一个步骤，对 y 也就是经度倒叙排列

# %%
# ds_xr['y']=ds_xr['y'][::-1]
ds_xr['x']=ds_xr['x'][::-1]

# %%
ds_xr
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 1080, y: 660)
# Coordinates:
#   * y            (y) float32 25.991667 25.975 25.958334 ... 15.025 15.008333
#   * x            (x) float32 122.99167 122.975 122.958336 ... 105.025 105.00833
#     spatial_ref  int32 0
# Data variables:
#     pro_surge    (y, x) float32 ...
# Attributes:
#     description:   The probability of storm surge >=1.0m
#     grid_mapping:  spatial_ref

# %%
ds_xr.to_netcdf(r'F:\03nginx_data\nmefc_download\TY_GROUP_RESULT\proSurge_TY2022_2021010416_gt1_0m_converted_asc_y.nc')

# %%
ds_xr.rio.to_raster(r'F:\03nginx_data\nmefc_download\TY_GROUP_RESULT\proSurge_TY2022_2021010416_gt1_0m_converted_desc_x.tif')
