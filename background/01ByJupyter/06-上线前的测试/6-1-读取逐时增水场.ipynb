# %%
import os
import pandas as pd
import numpy as np
import re
from datetime import datetime,timedelta
import arrow
import numpy as np
import netCDF4 as nc
import pandas as pd
import numpy.ma as ma
import matplotlib as mpl
import matplotlib.pyplot as pltz
import xarray as xar
import rioxarray

# %%
file_path:str=r'E:\05DATA\01nginx_data\nmefc_download\TY_GROUP_RESULT\TY2114_1631066272\result\fieldSurge_TY2114_1631066272_c0_p00_converted.nc'

# %%
ds_xr=xar.open_dataset(file_path,decode_times=False)
ds_xr
# Out:
# <xarray.Dataset>
# Dimensions:      (times: 120, x: 1080, y: 660)
# Coordinates:
#   * y            (y) float32 25.99 25.98 25.96 25.94 ... 15.06 15.04 15.02 15.01
#   * x            (x) float32 105.0 105.0 105.0 105.1 ... 122.9 123.0 123.0 123.0
#   * times        (times) float32 7.38e+05 7.38e+05 ... 7.38e+05 7.38e+05
#     spatial_ref  int32 ...
# Data variables:
#     surge        (times, y, x) float32 ...
# Attributes:
#     description:   Storm Surge Field
#     grid_mapping:  spatial_ref

# %%
gmt_start=datetime(2021,9,15,0,0)
gmt_start
# Out:
# datetime.datetime(2021, 9, 15, 0, 0)

# %%
num_times=120
np_dt_range = np.array([gmt_start + timedelta(hours=i) for i in range(num_times)])

# %%
to_save_file:str=r'E:\05DATA\01nginx_data\nmefc_download\TY_GROUP_RESULT\TY2114_1631066272\result\fieldSurge_TY2114_1631066272_c0_p00_to_test.nc'

# %%
# np_dt_range
ds_xr.coords['times']=np_dt_range

# %%
ds_xr.to_netcdf(to_save_file)

# %%
ds_xr.coords.get('times')[0]
# Out:
# <xarray.DataArray 'times' ()>
# array('2021-09-15T00:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     times    datetime64[ns] 2021-09-15

# %%
ds_xr.coords.get('times')[-1]
# Out:
# <xarray.DataArray 'times' ()>
# array('2021-09-19T23:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     times    datetime64[ns] 2021-09-19T23:00:00
