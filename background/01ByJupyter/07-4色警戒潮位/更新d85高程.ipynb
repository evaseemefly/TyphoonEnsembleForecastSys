# %%
import os
import pandas as pd

# %%
read_file_path:str=r'./../ignore_data/sites_wl4_四色警戒潮位_含85基面.csv'

# %%
tab_columns=['name','code','wl1','wl2','wl3','wl4','d85','MSL','lon','lat']

# %%
df=pd.read_csv(read_file_path,names=tab_columns)

# %%
df.head()
# Out:
#     name        code    wl1    wl2    wl3    wl4  d85    MSL       lon  \
# 0   '东港'  'DONGGANG'  766.0  796.0  796.0  796.0  361  361.0  124.1667
# 1  '小长山'    'XIAOCS'  484.0  508.0  508.0  508.0  234  211.0  122.6667
# 2   '皮口'     'PIKOU'  520.0  545.0  545.0  545.0  223  228.0  122.3533
# 3  '老虎滩'  'LAOHUTAN'  438.0  466.0  466.0  466.0  228  229.0  121.6833
# 4  '长兴岛'   'CHANGXD'  304.0  337.0  337.0  337.0  153  154.0  121.2550
#
#        lat
# 0  39.8333
# 1  39.2333
# 2  39.3650
# 3  38.8667
# 4  39.4767

# %%
df.shape
# Out:
# (208, 10)

# %%
df.shape[0]
# Out:
# 208

# %%
df.iloc[0]
# Out:
# name          '东港'
# code    'DONGGANG'
# wl1          766.0
# wl2          796.0
# wl3          796.0
# wl4          796.0
# d85            361
# MSL          361.0
# lon       124.1667
# lat        39.8333
# Name: 0, dtype: object

# %%
for index in range(df.shape[0]):
    print(df.iloc[index])
# Out:
# name          '东港'
# code    'DONGGANG'
# wl1          766.0
# wl2          796.0
# wl3          796.0
# wl4          796.0
# d85            361
# MSL          361.0
# lon       124.1667
# lat        39.8333
# Name: 0, dtype: object
# name       '小长山'
# code    'XIAOCS'
# wl1        484.0
# wl2        508.0
# wl3        508.0
# wl4        508.0
# d85          234
# MSL        211.0
# lon     122.6667
# lat      39.2333
# Name: 1, dtype: object
# name        '皮口'
# code     'PIKOU'
# wl1        520.0
# wl2        545.0
# wl3        545.0
# wl4        545.0
# d85          223
# MSL        228.0
# lon     122.3533
# lat       39.365
# Name: 2, dtype: object
# name         '老虎滩'
# code    'LAOHUTAN'
# wl1          438.0
# wl2          466.0
# wl3          466.0
# wl4          466.0
# d85            228
# MSL          229.0
# lon       121.6833
# lat        38.8667
# Name: 3, dtype: object
# name        '长兴岛'
# code    'CHANGXD'
# wl1         304.0
# wl2         337.0
# wl3         337.0
# ...
